# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# # Importing the dataset

# %%
data=pd.read_csv('ipl_dataset.csv')

# %%
data
# Out:
#                                         full_scorecard  \
# 0    https://stats.espncricinfo.com/ci/engine/match...
# 1    https://stats.espncricinfo.com/ci/engine/match...
# 2    https://stats.espncricinfo.com/ci/engine/match...
# 3    https://stats.espncricinfo.com/ci/engine/match...
# 4    https://stats.espncricinfo.com/ci/engine/match...
# ..                                                 ...
# 953  https://stats.espncricinfo.com/ci/engine/match...
# 954  https://stats.espncricinfo.com/ci/engine/match...
# 955  https://stats.espncricinfo.com/ci/engine/match...
# 956  https://stats.espncricinfo.com/ci/engine/match...
# 957  https://stats.espncricinfo.com/ci/engine/match...
#
#                            team1                  team2  team1_score  \
# 0            Chennai Super Kings  Kolkata Knight Riders        131.0
# 1                 Mumbai Indians         Delhi Capitals        177.0
# 2    Royal Challengers Bangalore           Punjab Kings        205.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   full_scorecard    958 non-null    object
#  1   team1             958 non-null    object
#  2   team2             950 non-null    object
#  3   team1_score       930 non-null    float64
#  4   team2_score       948 non-null    float64
#  5   toss_winner       950 non-null    object
#  6   toss_choice       958 non-null    object
#  7   winner            958 non-null    object
#  8   margin            958 non-null    object
#  9   man_of_the_match  950 non-null    object
#  10  stadium           950 non-null    object
#  11  place             874 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 89.9+ KB

# %%
data.dropna(inplace=True)

# %%
data.columns
# Out:
# Index(['full_scorecard', 'team1', 'team2', 'team1_score', 'team2_score',
#        'toss_winner', 'toss_choice', 'winner', 'margin', 'man_of_the_match',
#        'stadium', 'place'],
#       dtype='object')

# %%
data.drop(['full_scorecard','margin','man_of_the_match'], axis=1,inplace=True)

# %%
data
# Out:
#                            team1                  team2  team1_score  \
# 0            Chennai Super Kings  Kolkata Knight Riders        131.0
# 1                 Mumbai Indians         Delhi Capitals        177.0
# 2    Royal Challengers Bangalore           Punjab Kings        205.0
# 3           Lucknow Super Giants         Gujarat Titans        158.0
# 4               Rajasthan Royals    Sunrisers Hyderabad        210.0
# ..                           ...                    ...          ...
# 952              Deccan Chargers    Chennai Super Kings        147.0
# 954              Kings XI Punjab       Rajasthan Royals        221.0
# 955             Rajasthan Royals       Delhi Daredevils        192.0
# 956              Kings XI Punjab    Chennai Super Kings        112.0
# 957          Chennai Super Kings       Rajasthan Royals        163.0
#
#      team2_score            toss_winner toss_choice    winner  \
# 0          133.0  Kolkata Knight Riders       Field       KKR
# ...

# %%
data['team1'].unique()
# Out:
# array(['Chennai Super Kings', 'Mumbai Indians',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Rajasthan Royals', 'Kolkata Knight Riders', 'Punjab Kings',
#        'Gujarat Titans', 'Delhi Capitals', 'Sunrisers Hyderabad',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Rising Pune Supergiants',
#        'Pune Warriors', 'Deccan Chargers', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %%
data['team1'].nunique()
# Out:
# 18

# %%
data['team1'].replace({'Chennai Super Kings': 'CSK' ,'Mumbai Indians':'MI','Royal Challengers Bangalore':'RCB','Lucknow Super Giants':'LSG','Rajasthan Royals':'RR','Kolkata Knight Riders':'KKR','Punjab Kings':'PBKS','Kings XI Punjab':'PBKS','Gujarat Titans':'GT','Delhi Capitals':'DC','Delhi Daredevils':'DC','Sunrisers Hyderabad':'SRH','Gujarat Lions':'GL','Rising Pune Supergiants':'RPS','Rising Pune Supergiant':'RPS','Pune Warriors':'PW','Deccan Chargers':'DC','Kochi Tuskers Kerala':'KTK'},inplace=True)

# %%
data
# Out:
#     team1                  team2  team1_score  team2_score  \
# 0     CSK  Kolkata Knight Riders        131.0        133.0
# 1      MI         Delhi Capitals        177.0        179.0
# 2     RCB           Punjab Kings        205.0        208.0
# 3     LSG         Gujarat Titans        158.0        161.0
# 4      RR    Sunrisers Hyderabad        210.0        149.0
# ..    ...                    ...          ...          ...
# 952    DC    Chennai Super Kings        147.0        148.0
# 954  PBKS       Rajasthan Royals        221.0        180.0
# 955    RR       Delhi Daredevils        192.0         87.0
# 956  PBKS    Chennai Super Kings        112.0        116.0
# 957   CSK       Rajasthan Royals        163.0        164.0
#
#                toss_winner toss_choice    winner  \
# 0    Kolkata Knight Riders       Field       KKR
# 1           Delhi Capitals       Field  Capitals
# 2             Punjab Kings       Field    Punjab
# 3           Gujarat Titans       Field    Titans
# ...

# %%
data['team1'].unique()
# Out:
# array(['CSK', 'MI', 'RCB', 'LSG', 'RR', 'KKR', 'PBKS', 'GT', 'DC', 'SRH',
#        'GL', 'RPS', 'PW', 'KTK'], dtype=object)

# %%
data['team1'].nunique()
# Out:
# 14

# %%
data['team2'].replace({'Chennai Super Kings': 'CSK' ,'Mumbai Indians':'MI','Royal Challengers Bangalore':'RCB','Lucknow Super Giants':'LSG','Rajasthan Royals':'RR','Kolkata Knight Riders':'KKR','Punjab Kings':'PBKS','Kings XI Punjab':'PBKS','Gujarat Titans':'GT','Delhi Capitals':'DC','Delhi Daredevils':'DC','Sunrisers Hyderabad':'SRH','Gujarat Lions':'GL','Rising Pune Supergiants':'RPS','Rising Pune Supergiant':'RPS','Pune Warriors':'PW','Deccan Chargers':'DC','Kochi Tuskers Kerala':'KTK'},inplace=True)

# %%
data
# Out:
#     team1 team2  team1_score  team2_score            toss_winner toss_choice  \
# 0     CSK   KKR        131.0        133.0  Kolkata Knight Riders       Field
# 1      MI    DC        177.0        179.0         Delhi Capitals       Field
# 2     RCB  PBKS        205.0        208.0           Punjab Kings       Field
# 3     LSG    GT        158.0        161.0         Gujarat Titans       Field
# 4      RR   SRH        210.0        149.0    Sunrisers Hyderabad       Field
# ..    ...   ...          ...          ...                    ...         ...
# 952    DC   CSK        147.0        148.0        Deccan Chargers         Bat
# 954  PBKS    RR        221.0        180.0       Rajasthan Royals       Field
# 955    RR    DC        192.0         87.0       Delhi Daredevils       Field
# 956  PBKS   CSK        112.0        116.0        Kings XI Punjab         Bat
# 957   CSK    RR        163.0        164.0       Rajasthan Royals       Field
#
# ...

# %%
data['team2'].unique()
# Out:
# array(['KKR', 'DC', 'PBKS', 'GT', 'SRH', 'RCB', 'LSG', 'MI', 'CSK', 'RR',
#        'RPS', 'GL', 'PW', 'KTK'], dtype=object)

# %%
data['team2'].nunique()
# Out:
# 14

# %%
data['toss_winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Sunrisers Hyderabad',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Mumbai Indians', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Rising Pune Supergiants', 'Pune Warriors',
#        'Deccan Chargers', 'Kochi Tuskers Kerala'], dtype=object)

# %%
data['toss_winner'].nunique()
# Out:
# 18

# %%
data['toss_winner'].replace({'Chennai Super Kings': 'CSK' ,'Mumbai Indians':'MI','Royal Challengers Bangalore':'RCB','Lucknow Super Giants':'LSG','Rajasthan Royals':'RR','Kolkata Knight Riders':'KKR','Punjab Kings':'PBKS','Kings XI Punjab':'PBKS','Gujarat Titans':'GT','Delhi Capitals':'DC','Delhi Daredevils':'DC','Sunrisers Hyderabad':'SRH','Gujarat Lions':'GL','Rising Pune Supergiants':'RPS','Rising Pune Supergiant':'RPS','Pune Warriors':'PW','Deccan Chargers':'DC','Kochi Tuskers Kerala':'KTK'},inplace=True)

# %%
data['toss_winner'].unique()
# Out:
# array(['KKR', 'DC', 'PBKS', 'GT', 'SRH', 'RCB', 'LSG', 'MI', 'CSK', 'RR',
#        'RPS', 'GL', 'PW', 'KTK'], dtype=object)

# %%
data
# Out:
#     team1 team2  team1_score  team2_score toss_winner toss_choice    winner  \
# 0     CSK   KKR        131.0        133.0         KKR       Field       KKR
# 1      MI    DC        177.0        179.0          DC       Field  Capitals
# 2     RCB  PBKS        205.0        208.0        PBKS       Field    Punjab
# 3     LSG    GT        158.0        161.0          GT       Field    Titans
# 4      RR   SRH        210.0        149.0         SRH       Field    Royals
# ..    ...   ...          ...          ...         ...         ...       ...
# 952    DC   CSK        147.0        148.0          DC         Bat     Super
# 954  PBKS    RR        221.0        180.0          RR       Field     Kings
# 955    RR    DC        192.0         87.0          DC       Field    Royals
# 956  PBKS   CSK        112.0        116.0        PBKS         Bat     Super
# 957   CSK    RR        163.0        164.0          RR       Field    Royals
#
#                                      stadium   place
# ...

# %%
data['winner'].unique()
# Out:
# array(['KKR', 'Capitals', 'Punjab', 'Titans', 'Royals', 'RCB', 'Super',
#        'Sunrisers', 'Mumbai', 'Tied', 'Kings', 'Daredevils', 'Supergiant',
#        'Guj', 'Supergiants', 'No', 'Warriors', 'Chargers', 'Kochi'],
#       dtype=object)

# %%
data['winner'].nunique()
# Out:
# 19

# %%
data['place'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Kolkata', 'Ahmedabad', 'Chepauk', 'Delhi',
#        'Abu Dhabi', 'Jaipur', 'Bangalore', 'Uppal', 'Mohali',
#        'Visakhapatnam', 'Bengaluru', 'Indore', 'Rajkot', 'Kanpur',
#        'Raipur', 'Motera', 'Ranchi', 'Cuttack', 'Dharamsala', 'Kochi',
#        'Jamtha', 'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein'],
#       dtype=object)

# %%
data['place'].nunique()
# Out:
# 31

# %%
data['place'].replace({'Bengaluru':'Bangalore'},inplace=True)

# %%
data['place'].value_counts()
# Out:
# place
# Mumbai            168
# Kolkata            76
# Delhi              75
# Bangalore          73
# Chepauk            67
# Uppal              63
# Mohali             55
# Pune               51
# Jaipur             46
# Abu Dhabi          37
# Durban             15
# Visakhapatnam      13
# Motera             12
# Centurion          11
# Rajkot             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ahmedabad           7
# Port Elizabeth      7
# Cape Town           6
# Raipur              6
# Ranchi              6
# Kochi               4
# Kanpur              4
# Jamtha              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
data['stadium'].unique()
# Out:
# array(['Wankhede Stadium', 'Brabourne Stadium',
#        'Dr DY Patil Sports Academy',
#        'Maharashtra Cricket Association Stadium', 'Eden Gardens',
#        'Narendra Modi Stadium', 'MA Chidambaram Stadium',
#        'Arun Jaitley Stadium', 'Zayed Cricket Stadium',
#        'Sheikh Zayed Stadium', 'Sawai Mansingh Stadium',
#        'Feroz Shah Kotla', 'M Chinnaswamy Stadium',
#        'Rajiv Gandhi International Stadium',
#        'Punjab Cricket Association IS Bindra Stadium',
#        'Andhra Cricket Association-Visakhapatnam District Cricket Association Stadium',
#        'Holkar Cricket Stadium', 'Saurashtra Cricket Association Stadium',
#        'Green Park',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'Sardar Patel Stadium', 'Punjab Cricket Association Stadium',
#        'JSCA International Stadium Complex', 'Barabati Stadium',
#        'Subrata Roy Sahara Stadium',
# ...

# %%
data['stadium'].nunique()
# Out:
# 37

# %%
data['stadium'].value_counts()
# Out:
# stadium
# Wankhede Stadium                                                                 104
# Eden Gardens                                                                      76
# M Chinnaswamy Stadium                                                             73
# Feroz Shah Kotla                                                                  71
# MA Chidambaram Stadium                                                            67
# Rajiv Gandhi International Stadium                                                63
# Sawai Mansingh Stadium                                                            46
# Dr DY Patil Sports Academy                                                        37
# Maharashtra Cricket Association Stadium                                           34
# Punjab Cricket Association Stadium                                                34
# Zayed Cricket Stadium                                                             28
# ...

# %%
data.columns
# Out:
# Index(['team1', 'team2', 'team1_score', 'team2_score', 'toss_winner',
#        'toss_choice', 'winner', 'stadium', 'place'],
#       dtype='object')

# %% [markdown]
# # Groupby method

# %%
max=data.groupby(['place','stadium'])['team1_score'].mean().reset_index()

# %%
max
# Out:
#              place                                            stadium  \
# 0        Abu Dhabi                               Sheikh Zayed Stadium
# 1        Abu Dhabi                              Zayed Cricket Stadium
# 2        Ahmedabad                              Narendra Modi Stadium
# 3        Bangalore                              M Chinnaswamy Stadium
# 4     Bloemfontein                                    OUTsurance Oval
# 5        Cape Town                                           Newlands
# 6        Centurion                                    SuperSport Park
# 7          Chepauk                             MA Chidambaram Stadium
# 8          Cuttack                                   Barabati Stadium
# 9            Delhi                               Arun Jaitley Stadium
# 10           Delhi                                   Feroz Shah Kotla
# 11      Dharamsala       Himachal Pradesh Cricket Association Stadium
# ...

# %%
max['team1_score'].max()
# Out:
# 195.0

# %%
max['team1_score'].min()
# Out:
# 135.0

# %% [markdown]
# # Groupby method

# %%
min=data.groupby(['place','stadium'])['team2_score'].mean().reset_index()

# %%
min
# Out:
#              place                                            stadium  \
# 0        Abu Dhabi                               Sheikh Zayed Stadium
# 1        Abu Dhabi                              Zayed Cricket Stadium
# 2        Ahmedabad                              Narendra Modi Stadium
# 3        Bangalore                              M Chinnaswamy Stadium
# 4     Bloemfontein                                    OUTsurance Oval
# 5        Cape Town                                           Newlands
# 6        Centurion                                    SuperSport Park
# 7          Chepauk                             MA Chidambaram Stadium
# 8          Cuttack                                   Barabati Stadium
# 9            Delhi                               Arun Jaitley Stadium
# 10           Delhi                                   Feroz Shah Kotla
# 11      Dharamsala       Himachal Pradesh Cricket Association Stadium
# ...

# %%
min['team2_score'].max()
# Out:
# 182.25

# %%
min['team2_score'].min()
# Out:
# 119.0

# %%
data
# Out:
#     team1 team2  team1_score  team2_score toss_winner toss_choice    winner  \
# 0     CSK   KKR        131.0        133.0         KKR       Field       KKR
# 1      MI    DC        177.0        179.0          DC       Field  Capitals
# 2     RCB  PBKS        205.0        208.0        PBKS       Field    Punjab
# 3     LSG    GT        158.0        161.0          GT       Field    Titans
# 4      RR   SRH        210.0        149.0         SRH       Field    Royals
# ..    ...   ...          ...          ...         ...         ...       ...
# 952    DC   CSK        147.0        148.0          DC         Bat     Super
# 954  PBKS    RR        221.0        180.0          RR       Field     Kings
# 955    RR    DC        192.0         87.0          DC       Field    Royals
# 956  PBKS   CSK        112.0        116.0        PBKS         Bat     Super
# 957   CSK    RR        163.0        164.0          RR       Field    Royals
#
#                                      stadium   place
# ...

# %%
data['team1_score'].max()
# Out:
# 263.0

# %%
data['team1_score'].min()
# Out:
# 67.0

# %%
data['team2_score'].max()
# Out:
# 223.0

# %%
data['team2_score'].min()
# Out:
# 2.0

# %% [markdown]
# # Groupby method

# %%
data.groupby(['team1'])['team1_score'].mean().reset_index()
# Out:
#    team1  team1_score
# 0    CSK   168.078431
# 1     DC   158.858268
# 2     GL   161.928571
# 3     GT   162.285714
# 4    KKR   161.413043
# 5    KTK   144.142857
# 6    LSG   178.500000
# 7     MI   166.643478
# 8   PBKS   162.373832
# 9     PW   148.650000
# 10   RCB   167.831579
# 11   RPS   166.000000
# 12    RR   160.963415
# 13   SRH   162.969697

# %%
data.groupby(['team2'])['team2_score'].mean().reset_index()
# Out:
#    team2  team2_score
# 0    CSK   153.536585
# 1     DC   150.300699
# 2     GL   161.812500
# 3     GT   169.666667
# 4    KKR   148.727273
# 5    KTK   126.166667
# 6    LSG   160.000000
# 7     MI   151.555556
# 8   PBKS   154.090909
# 9     PW   135.400000
# 10   RCB   147.811881
# 11   RPS   140.400000
# 12    RR   151.333333
# 13   SRH   148.692308

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai         122
# Super          116
# KKR            103
# RCB             92
# Royals          89
# Kings           75
# Sunrisers       65
# Daredevils      62
# Chargers        29
# Capitals        24
# Guj             13
# Titans          12
# Warriors        12
# Tied            11
# Supergiant      10
# Punjab          10
# Supergiants      5
# Kochi            5
# No               1
# Name: count, dtype: int64

# %%
data['winner'].unique()
# Out:
# array(['KKR', 'Capitals', 'Punjab', 'Titans', 'Royals', 'RCB', 'Super',
#        'Sunrisers', 'Mumbai', 'Tied', 'Kings', 'Daredevils', 'Supergiant',
#        'Guj', 'Supergiants', 'No', 'Warriors', 'Chargers', 'Kochi'],
#       dtype=object)

# %%
data['winner'].replace({'KKR': 'KKR' ,'Mumbai':'MI','Royals':'RR','RCB':'RCB','Lucknow Super Giants':'LSG','Rajasthan Royals':'RR','Super':'CSK','Punjab':'PBKS','Kings':'PBKS','Titans':'GT','Capitals':'DC','Daredevils':'DC','Sunrisers':'SRH','Guj':'GL','Supergiant':'RPS','Supergiants':'RPS','Warriors':'PW','Chargers':'DC','Kochi':'KTK'},inplace=True)

# %%
data['winner'].unique()
# Out:
# array(['KKR', 'DC', 'PBKS', 'GT', 'RR', 'RCB', 'CSK', 'SRH', 'MI', 'Tied',
#        'RPS', 'GL', 'No', 'PW', 'KTK'], dtype=object)

# %%
data
# Out:
#     team1 team2  team1_score  team2_score toss_winner toss_choice winner  \
# 0     CSK   KKR        131.0        133.0         KKR       Field    KKR
# 1      MI    DC        177.0        179.0          DC       Field     DC
# 2     RCB  PBKS        205.0        208.0        PBKS       Field   PBKS
# 3     LSG    GT        158.0        161.0          GT       Field     GT
# 4      RR   SRH        210.0        149.0         SRH       Field     RR
# ..    ...   ...          ...          ...         ...         ...    ...
# 952    DC   CSK        147.0        148.0          DC         Bat    CSK
# 954  PBKS    RR        221.0        180.0          RR       Field   PBKS
# 955    RR    DC        192.0         87.0          DC       Field     RR
# 956  PBKS   CSK        112.0        116.0        PBKS         Bat    CSK
# 957   CSK    RR        163.0        164.0          RR       Field     RR
#
#                                      stadium   place
# ...

# %% [markdown]
# # Groupby method

# %%
data.groupby(['team1','place','stadium'])['team1_score'].mean().reset_index()
# Out:
#     team1          place                                            stadium  \
# 0     CSK      Abu Dhabi                               Sheikh Zayed Stadium
# 1     CSK      Abu Dhabi                              Zayed Cricket Stadium
# 2     CSK      Bangalore                              M Chinnaswamy Stadium
# 3     CSK      Centurion                                    SuperSport Park
# 4     CSK        Chepauk                             MA Chidambaram Stadium
# ..    ...            ...                                                ...
# 222   SRH           Pune                         Subrata Roy Sahara Stadium
# 223   SRH         Raipur   Shaheed Veer Narayan Singh International Stadium
# 224   SRH          Uppal                 Rajiv Gandhi International Stadium
# 225   SRH  Visakhapatnam  Andhra Cricket Association-Visakhapatnam Distr...
# 226   SRH  Visakhapatnam  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
#
#      team1_score
# 0     191.000000
# 1     157.000000
# ...

# %%
data.groupby(['team2','place','stadium'])['team2_score'].mean().reset_index()
# Out:
#     team2          place                                            stadium  \
# 0     CSK      Abu Dhabi                              Zayed Cricket Stadium
# 1     CSK      Bangalore                              M Chinnaswamy Stadium
# 2     CSK      Cape Town                                           Newlands
# 3     CSK        Chepauk                             MA Chidambaram Stadium
# 4     CSK        Cuttack                                   Barabati Stadium
# ..    ...            ...                                                ...
# 224   SRH           Pune            Maharashtra Cricket Association Stadium
# 225   SRH         Rajkot             Saurashtra Cricket Association Stadium
# 226   SRH         Ranchi                 JSCA International Stadium Complex
# 227   SRH          Uppal                 Rajiv Gandhi International Stadium
# 228   SRH  Visakhapatnam  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
#
#      team2_score
# 0     162.250000
# 1     165.500000
# ...

# %%
data
# Out:
#     team1 team2  team1_score  team2_score toss_winner toss_choice winner  \
# 0     CSK   KKR        131.0        133.0         KKR       Field    KKR
# 1      MI    DC        177.0        179.0          DC       Field     DC
# 2     RCB  PBKS        205.0        208.0        PBKS       Field   PBKS
# 3     LSG    GT        158.0        161.0          GT       Field     GT
# 4      RR   SRH        210.0        149.0         SRH       Field     RR
# ..    ...   ...          ...          ...         ...         ...    ...
# 952    DC   CSK        147.0        148.0          DC         Bat    CSK
# 954  PBKS    RR        221.0        180.0          RR       Field   PBKS
# 955    RR    DC        192.0         87.0          DC       Field     RR
# 956  PBKS   CSK        112.0        116.0        PBKS         Bat    CSK
# 957   CSK    RR        163.0        164.0          RR       Field     RR
#
#                                      stadium   place
# ...

# %%
data['winner'].value_counts()
# Out:
# winner
# MI      122
# CSK     116
# DC      115
# KKR     103
# RCB      92
# RR       89
# PBKS     85
# SRH      65
# RPS      15
# GL       13
# GT       12
# PW       12
# Tied     11
# KTK       5
# No        1
# Name: count, dtype: int64

# %%
sns.set(rc={'axes.facecolor':'skyblue','axes.grid':True})

# %% [markdown]
# # Team wise winning count visualisation

# %%
count=sns.countplot(x=data['winner'],order=data['winner'].value_counts().index)
for container in count.containers:
    count.bar_label(container)

# %% [markdown]
# # Groupby method

# %%
first=data.groupby(['team1'])['team1_score'].mean().reset_index()

# %%
first
# Out:
#    team1  team1_score
# 0    CSK   168.078431
# 1     DC   158.858268
# 2     GL   161.928571
# 3     GT   162.285714
# 4    KKR   161.413043
# 5    KTK   144.142857
# 6    LSG   178.500000
# 7     MI   166.643478
# 8   PBKS   162.373832
# 9     PW   148.650000
# 10   RCB   167.831579
# 11   RPS   166.000000
# 12    RR   160.963415
# 13   SRH   162.969697

# %% [markdown]
# # Team wise 1st innings score average visualisation

# %%
count=sns.barplot(x=first['team1'],y=first['team1_score'])
#for container in count.containers:
    #count.bar_label(container)

# %%
second=data.groupby(['team2'])['team2_score'].mean().reset_index()

# %% [markdown]
# # Team wise 2nd innings score average visualisation

# %%
count=sns.barplot(x=second['team2'],y=second['team2_score'])
#for container in count.containers:
    #count.bar_label(container)

# %%
data
# Out:
#     team1 team2  team1_score  team2_score toss_winner toss_choice winner  \
# 0     CSK   KKR        131.0        133.0         KKR       Field    KKR
# 1      MI    DC        177.0        179.0          DC       Field     DC
# 2     RCB  PBKS        205.0        208.0        PBKS       Field   PBKS
# 3     LSG    GT        158.0        161.0          GT       Field     GT
# 4      RR   SRH        210.0        149.0         SRH       Field     RR
# ..    ...   ...          ...          ...         ...         ...    ...
# 952    DC   CSK        147.0        148.0          DC         Bat    CSK
# 954  PBKS    RR        221.0        180.0          RR       Field   PBKS
# 955    RR    DC        192.0         87.0          DC       Field     RR
# 956  PBKS   CSK        112.0        116.0        PBKS         Bat    CSK
# 957   CSK    RR        163.0        164.0          RR       Field     RR
#
#                                      stadium   place
# ...

# %% [markdown]
# # Splitting the dataset into the training set and test set

# %%
from sklearn.model_selection import train_test_split

# %%
future=data.drop(['winner','team2_score'],axis=1)
target=data['winner']

# %%
future
# Out:
#     team1 team2  team1_score toss_winner toss_choice  \
# 0     CSK   KKR        131.0         KKR       Field
# 1      MI    DC        177.0          DC       Field
# 2     RCB  PBKS        205.0        PBKS       Field
# 3     LSG    GT        158.0          GT       Field
# 4      RR   SRH        210.0         SRH       Field
# ..    ...   ...          ...         ...         ...
# 952    DC   CSK        147.0          DC         Bat
# 954  PBKS    RR        221.0          RR       Field
# 955    RR    DC        192.0          DC       Field
# 956  PBKS   CSK        112.0        PBKS         Bat
# 957   CSK    RR        163.0          RR       Field
#
#                                      stadium   place
# 0                           Wankhede Stadium  Mumbai
# 1                          Brabourne Stadium  Mumbai
# 2                 Dr DY Patil Sports Academy  Mumbai
# 3                           Wankhede Stadium  Mumbai
# 4    Maharashtra Cricket Association Stadium    Pune
# ...

# %%
target
# Out:
# 0       KKR
# 1        DC
# 2      PBKS
# 3        GT
# 4        RR
#        ...
# 952     CSK
# 954    PBKS
# 955      RR
# 956     CSK
# 957      RR
# Name: winner, Length: 856, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(pd.get_dummies(future),target,test_size=0.2)

# %%
x_train
# Out:
#      team1_score  team1_CSK  team1_DC  team1_GL  team1_GT  team1_KKR  \
# 494        163.0      False     False     False     False       True
# 192        189.0      False      True     False     False      False
# 688        114.0      False      True     False     False      False
# 333        213.0      False     False     False     False      False
# 556        126.0      False     False     False     False      False
# ..           ...        ...       ...       ...       ...        ...
# 949        165.0      False      True     False     False      False
# 420        206.0      False     False     False     False      False
# 439        184.0      False      True     False     False      False
# 660        146.0      False     False     False     False      False
# 21         216.0       True     False     False     False      False
#
#      team1_KTK  team1_LSG  team1_MI  team1_PBKS  ...  place_Mohali  \
# 494      False      False     False       False  ...         False
# ...

# %%
y_train
# Out:
# 494    KKR
# 192     DC
# 688    CSK
# 333    RCB
# 556    SRH
#       ...
# 949    RCB
# 420     MI
# 439     RR
# 660     DC
# 21     CSK
# Name: winner, Length: 684, dtype: object

# %%
x_test
# Out:
#      team1_score  team1_CSK  team1_DC  team1_GL  team1_GT  team1_KKR  \
# 906        208.0       True     False     False     False      False
# 76         187.0      False     False     False     False       True
# 956        112.0      False     False     False     False      False
# 228        213.0      False     False     False     False      False
# 629        148.0      False     False     False     False      False
# ..           ...        ...       ...       ...       ...        ...
# 827        139.0      False     False     False     False       True
# 667        190.0      False     False     False     False       True
# 577        169.0       True     False     False     False      False
# 565        154.0      False     False     False     False       True
# 287        174.0      False     False     False     False      False
#
#      team1_KTK  team1_LSG  team1_MI  team1_PBKS  ...  place_Mohali  \
# 906      False      False     False       False  ...         False
# ...

# %%
y_test
# Out:
# 906    CSK
# 76     KKR
# 956    CSK
# 228    RCB
# 629     MI
#       ...
# 827    CSK
# 667    KKR
# 577    CSK
# 565    RCB
# 287     MI
# Name: winner, Length: 172, dtype: object

# %% [markdown]
# # Fitting RANDOM FOREST CLASSIFIER to the training set

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF=RandomForestClassifier()

# %%
model=RF.fit(x_train,y_train)

# %% [markdown]
# # Predicting the test set results

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array(['MI', 'RCB', 'CSK', 'KKR', 'MI', 'GL', 'DC', 'MI', 'DC', 'MI',
#        'CSK', 'GT', 'CSK', 'KKR', 'RR', 'SRH', 'KKR', 'GT', 'CSK', 'CSK',
#        'DC', 'GL', 'RCB', 'PBKS', 'MI', 'SRH', 'SRH', 'MI', 'MI', 'MI',
#        'MI', 'RCB', 'KKR', 'DC', 'MI', 'RCB', 'RCB', 'PBKS', 'KKR', 'RR',
#        'MI', 'RR', 'DC', 'MI', 'RR', 'KKR', 'PBKS', 'RPS', 'RCB', 'KKR',
#        'RCB', 'KKR', 'CSK', 'RCB', 'RR', 'CSK', 'MI', 'MI', 'SRH', 'DC',
#        'SRH', 'RCB', 'MI', 'RCB', 'MI', 'CSK', 'KKR', 'RCB', 'KKR', 'RCB',
#        'KKR', 'KKR', 'KKR', 'KKR', 'RR', 'CSK', 'KKR', 'RR', 'CSK', 'RPS',
#        'RR', 'MI', 'GL', 'CSK', 'CSK', 'DC', 'MI', 'PBKS', 'CSK', 'PBKS',
#        'MI', 'RR', 'CSK', 'KKR', 'RR', 'CSK', 'KKR', 'RCB', 'Tied', 'CSK',
#        'RR', 'DC', 'SRH', 'KKR', 'RPS', 'PBKS', 'RCB', 'SRH', 'CSK', 'MI',
#        'PBKS', 'KKR', 'MI', 'KKR', 'PBKS', 'RCB', 'MI', 'KKR', 'KKR',
#        'DC', 'KKR', 'DC', 'PBKS', 'SRH', 'RR', 'KKR', 'KKR', 'RR', 'SRH',
# ...

# %% [markdown]
# # Machine performance score

# %%
model.score(x_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5581395348837209
